# %% [markdown]
# <a href="https://colab.research.google.com/github/sriharshitha06/Machine-Learning/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("lava18/google-play-store-apps")
# Out:
# ...
# 100%|██████████| 1.94M/1.94M [00:00<00:00, 115MB/s]
# Extracting files...
